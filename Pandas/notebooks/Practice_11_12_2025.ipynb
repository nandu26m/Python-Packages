# %% [markdown]
# <a href="https://colab.research.google.com/github/nandu26m/Python-Packages/blob/main/Pandas/notebooks/Practice_11_12_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #A. DataFrame Basics (1–20)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Sample data for practice

data = {
    "track_id": ["T001","T002","T003","T004","T005"],
    "track_name": ["Night Sky", "Falling Stars", "Lost Dreams", "Ocean Blue", "Fire Heart"],
    "track_number": [1, 5, 3, 2, 8],
    "track_popularity": [78, 85, 60, 92, 55],
    "track_duration_ms": [210000, 195000, 235000, 180000, 200000],
    "explicit": [False, True, False, False, True],
    "artist_name": ["Astra", "Nova", "Echo", "BlueWave", "Ignis"],
    "artist_popularity": [88, 70, 65, 74, 90],
    "artist_followers": [150000, 95000, 40000, 120000, 300000],
    "artist_genres": [
        ["pop","indie"],
        ["electronic"],
        ["indie","ambient"],
        ["chill","ambient"],
        ["rock","metal"]
    ],
    "album_id": ["AL001","AL002","AL003","AL004","AL005"],
    "album_name": ["Skyline", "Gravity", "Dreamland", "Sea Breeze", "Blaze"],
    "album_release_date": ["2021-06-10", "2020-01-15", "2019-09-20", "2022-02-05", "2023-08-12"],
    "album_total_tracks": [12, 15, 9, 11, 13],
    "album_type": ["album", "single", "album", "album", "single"]
}

# %%
# Load data to DataFrame
df = pd.DataFrame(data)

# %%
#1. Show the first 3 rows
df.head(3)
# Out:
#   track_id     track_name  track_number  track_popularity  track_duration_ms  \
# 0     T001      Night Sky             1                78             210000
# 1     T002  Falling Stars             5                85             195000
# 2     T003    Lost Dreams             3                60             235000
#
#    explicit artist_name  artist_popularity  artist_followers  \
# 0     False       Astra                 88            150000
# 1      True        Nova                 70             95000
# 2     False        Echo                 65             40000
#
#       artist_genres album_id album_name album_release_date  \
# 0      [pop, indie]    AL001    Skyline         2021-06-10
# 1      [electronic]    AL002    Gravity         2020-01-15
# 2  [indie, ambient]    AL003  Dreamland         2019-09-20
#
#    album_total_tracks album_type
# 0                  12      album
# 1                  15     single
# 2                   9      album

# %%
#2. Show the last 3 rows
df.tail(3)
# Out:
#   track_id   track_name  track_number  track_popularity  track_duration_ms  \
# 2     T003  Lost Dreams             3                60             235000
# 3     T004   Ocean Blue             2                92             180000
# 4     T005   Fire Heart             8                55             200000
#
#    explicit artist_name  artist_popularity  artist_followers  \
# 2     False        Echo                 65             40000
# 3     False    BlueWave                 74            120000
# 4      True       Ignis                 90            300000
#
#       artist_genres album_id  album_name album_release_date  \
# 2  [indie, ambient]    AL003   Dreamland         2019-09-20
# 3  [chill, ambient]    AL004  Sea Breeze         2022-02-05
# 4     [rock, metal]    AL005       Blaze         2023-08-12
#
#    album_total_tracks album_type
# 2                   9      album
# 3                  11      album
# 4                  13     single

# %%
#3. Print all column names.
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'track_duration_ms', 'explicit', 'artist_name', 'artist_popularity',
#        'artist_followers', 'artist_genres', 'album_id', 'album_name',
#        'album_release_date', 'album_total_tracks', 'album_type'],
#       dtype='object')

# %%
#4. Print DataFrame shape.
df.shape
# Out:
# (5, 15)

# %%
#5. Show DataFrame info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            5 non-null      object
#  1   track_name          5 non-null      object
#  2   track_number        5 non-null      int64
#  3   track_popularity    5 non-null      int64
#  4   track_duration_ms   5 non-null      int64
#  5   explicit            5 non-null      bool
#  6   artist_name         5 non-null      object
#  7   artist_popularity   5 non-null      int64
#  8   artist_followers    5 non-null      int64
#  9   artist_genres       5 non-null      object
#  10  album_id            5 non-null      object
#  11  album_name          5 non-null      object
#  12  album_release_date  5 non-null      object
#  13  album_total_tracks  5 non-null      int64
#  14  album_type          5 non-null      object
# dtypes: bool(1), int64(6), object(8)
# ...

# %%
#6. Show summary statistics.

# First converting the 'album_release_date' column to 'datetime'
df['album_release_date'] = pd.to_datetime(df['album_release_date'])

print(df.describe(include=['object']))
print(df.describe(include=['number']))
print(df.describe(include=['datetime']))
# Out:
#        track_id track_name artist_name artist_genres album_id album_name  \
# count         5          5           5             5        5          5
# unique        5          5           5             5        5          5
# top        T001  Night Sky       Astra  [pop, indie]    AL001    Skyline
# freq          1          1           1             1        1          1
#
#        album_type
# count           5
# unique          2
# top         album
# freq            3
#        track_number  track_popularity  track_duration_ms  artist_popularity  \
# count      5.000000          5.000000           5.000000           5.000000
# mean       3.800000         74.000000      204000.000000          77.400000
# std        2.774887         15.953056       20432.816742          11.081516
# min        1.000000         55.000000      180000.000000          65.000000
# 25%        2.000000         60.000000      195000.000000          70.000000
# ...

# %%
#7. Check number of missing values in each column.
print(df.isnull().sum())
print(df.isna().sum())
# Out:
# track_id              0
# track_name            0
# track_number          0
# track_popularity      0
# track_duration_ms     0
# explicit              0
# artist_name           0
# artist_popularity     0
# artist_followers      0
# artist_genres         0
# album_id              0
# album_name            0
# album_release_date    0
# album_total_tracks    0
# album_type            0
# dtype: int64
# track_id              0
# track_name            0
# track_number          0
# track_popularity      0
# track_duration_ms     0
# explicit              0
# artist_name           0
# artist_popularity     0
# artist_followers      0
# artist_genres         0
# album_id              0
# album_name            0
# album_release_date    0
# album_total_tracks    0
# album_type            0
# dtype: int64

# %%
#8. Convert all column names to uppercase.
df.columns = df.columns.str.upper()
df.columns # The will return an 'Index' object and it has Pandas string-accessor support, so we can perform the above action but its not possible normal lists.
# Out:
# Index(['TRACK_ID', 'TRACK_NAME', 'TRACK_NUMBER', 'TRACK_POPULARITY',
#        'TRACK_DURATION_MS', 'EXPLICIT', 'ARTIST_NAME', 'ARTIST_POPULARITY',
#        'ARTIST_FOLLOWERS', 'ARTIST_GENRES', 'ALBUM_ID', 'ALBUM_NAME',
#        'ALBUM_RELEASE_DATE', 'ALBUM_TOTAL_TRACKS', 'ALBUM_TYPE'],
#       dtype='object')

# %%
#9. Convert all column names to title case.
print(f"Column names before modification:\n {df.columns}\n")
df.columns = df.columns.str.title()
print(f"Column names after modification:\n {df.columns}")
# Out:
# Column names before modification:
#  Index(['TRACK_ID', 'TRACK_NAME', 'TRACK_NUMBER', 'TRACK_POPULARITY',
#        'TRACK_DURATION_MS', 'EXPLICIT', 'ARTIST_NAME', 'ARTIST_POPULARITY',
#        'ARTIST_FOLLOWERS', 'ARTIST_GENRES', 'ALBUM_ID', 'ALBUM_NAME',
#        'ALBUM_RELEASE_DATE', 'ALBUM_TOTAL_TRACKS', 'ALBUM_TYPE'],
#       dtype='object')
#
# Column names after modification:
#  Index(['Track_Id', 'Track_Name', 'Track_Number', 'Track_Popularity',
#        'Track_Duration_Ms', 'Explicit', 'Artist_Name', 'Artist_Popularity',
#        'Artist_Followers', 'Artist_Genres', 'Album_Id', 'Album_Name',
#        'Album_Release_Date', 'Album_Total_Tracks', 'Album_Type'],
#       dtype='object')

# %%
#10. Select only numeric columns.
df.select_dtypes(include="number")
# Out:
#    Track_Number  Track_Popularity  Track_Duration_Ms  Artist_Popularity  \
# 0             1                78             210000                 88
# 1             5                85             195000                 70
# 2             3                60             235000                 65
# 3             2                92             180000                 74
# 4             8                55             200000                 90
#
#    Artist_Followers  Album_Total_Tracks
# 0            150000                  12
# 1             95000                  15
# 2             40000                   9
# 3            120000                  11
# 4            300000                  13

# %%
#11. Select only object columns.
df.select_dtypes(include="object")
# Out:
#   Track_Id     Track_Name Artist_Name     Artist_Genres Album_Id  Album_Name  \
# 0     T001      Night Sky       Astra      [pop, indie]    AL001     Skyline
# 1     T002  Falling Stars        Nova      [electronic]    AL002     Gravity
# 2     T003    Lost Dreams        Echo  [indie, ambient]    AL003   Dreamland
# 3     T004     Ocean Blue    BlueWave  [chill, ambient]    AL004  Sea Breeze
# 4     T005     Fire Heart       Ignis     [rock, metal]    AL005       Blaze
#
#   Album_Type
# 0      album
# 1     single
# 2      album
# 3      album
# 4     single

# %%
#12. Change album_release_date to datetime.
if df['Album_Release_Date'].dtypes == "datetime64[ns]":
  print(f"The column 'Album_Release_Date' is already 'datetime64[ns]'.")
else:
  df["Album_Release_Date"] = pd.to_datetime(df["Album_Release_Date"])
  print("The column 'Album_Release_Date' is converted to 'datetime64[ns]'.")
# Out:
# The column 'Album_Release_Date' is already 'datetime64[ns]'.

# %%
#13. Convert track_popularity to float.
df['Track_Popularity'] = df['Track_Popularity'].astype(float)
print(df['Track_Popularity'].dtype)
# Out:
# float64

# %%
#14. Rename artist_name to singer.
df.rename(columns = {"Artist_Name" : "Singer"}, inplace=True)
df.columns
# Out:
# Index(['Track_Id', 'Track_Name', 'Track_Number', 'Track_Popularity',
#        'Track_Duration_Ms', 'Explicit', 'Singer', 'Artist_Popularity',
#        'Artist_Followers', 'Artist_Genres', 'Album_Id', 'Album_Name',
#        'Album_Release_Date', 'Album_Total_Tracks', 'Album_Type'],
#       dtype='object')

# %%
#15. Add a new column track_duration_min (ms → minutes).
df['track_duration_min'] = (df['Track_Duration_Ms'] /1000 / 60).round(2)
print(df.head(5))
# Out:
#   Track_Id     Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 0     T001      Night Sky             1              78.0             210000
# 1     T002  Falling Stars             5              85.0             195000
# 2     T003    Lost Dreams             3              60.0             235000
# 3     T004     Ocean Blue             2              92.0             180000
# 4     T005     Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 0     False     Astra                 88            150000      [pop, indie]
# 1      True      Nova                 70             95000      [electronic]
# 2     False      Echo                 65             40000  [indie, ambient]
# 3     False  BlueWave                 74            120000  [chill, ambient]
# 4      True     Ignis                 90            300000     [rock, metal]
#
# ...

# %%
#16. Drop the column album_id.
print("Before:", df.columns)
df.drop(columns=['Album_Id'], inplace=True)
print("After:", df.columns)
# Out:
# Before: Index(['Track_Id', 'Track_Name', 'Track_Number', 'Track_Popularity',
#        'Track_Duration_Ms', 'Explicit', 'Singer', 'Artist_Popularity',
#        'Artist_Followers', 'Artist_Genres', 'Album_Id', 'Album_Name',
#        'Album_Release_Date', 'Album_Total_Tracks', 'Album_Type',
#        'track_duration_min'],
#       dtype='object')
# After: Index(['Track_Id', 'Track_Name', 'Track_Number', 'Track_Popularity',
#        'Track_Duration_Ms', 'Explicit', 'Singer', 'Artist_Popularity',
#        'Artist_Followers', 'Artist_Genres', 'Album_Name', 'Album_Release_Date',
#        'Album_Total_Tracks', 'Album_Type', 'track_duration_min'],
#       dtype='object')

# %%
#17. Drop first row from the DataFrame.
df.drop(index=df.index[0], inplace=True)

# %%
df = df.iloc[1:] # Keeps all rows from the second row onward

# %%
#18. Get DataFrame memory usage.
df.memory_usage(deep=True).sum()

memory = df.memory_usage(deep=True).sum() / (1024 ** 2)
print(f"DataFrame uses {memory:.2f} MB")
# Out:
# DataFrame uses 0.00 MB

# %%
#19. Check unique values in album_type.
print(df['Album_Type'].unique())
print(df['Album_Type'].nunique())
# Out:
# ['album' 'single']
# 2

# %%
#20. Count number of duplicates.

list_cols = [col for col in df.columns if df[col].apply(lambda x: isinstance(x, list)).any()]
print("Columns containing lists:", list_cols)
# Out:
# Columns containing lists: ['Artist_Genres']

# %%
for col in list_cols:
    df[col] = df[col].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Track_Id, Track_Name, Track_Number, Track_Popularity, Track_Duration_Ms, Explicit, Singer, Artist_Popularity, Artist_Followers, Artist_Genres, Album_Name, Album_Release_Date, Album_Total_Tracks, Album_Type, track_duration_min]
# Index: []

# %% [markdown]
# #B. Filtering & Querying (21–40)

# %%
#21. Show tracks with popularity > 80.
df[df['Track_Popularity'] > 80]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 3                 3.0

# %%
#22. Show tracks longer than 3 minutes.
df[df['track_duration_min'] > 3]
print(f"Count: {(df['track_duration_min'] > 3).sum()}")
# Out:
# Count: 2

# %%
#23. Filter rows where explicit == True.
df[df['Explicit'] == True]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers  Artist_Genres  \
# 4      True  Ignis                 90            300000  (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 4                3.33

# %%
#24. Get artists with followers > 100,000.
print(df[df['Artist_Followers'] > 100000])
print(f"{'-'*100}\nTotal count: {df[df['Artist_Followers'] > 100000].shape[0]}")
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 3                3.00
# 4                3.33
# ----------------------------------------------------------------------------------------------------
# Total count: 2

# %%
#25. Get tracks where artist_genres contains “pop”.
print(df[df['Artist_Genres'].apply(lambda x: 'rock' in x)].shape[0])
df[df['Artist_Genres'].apply(lambda x: 'rock' in x)]
# Out:
# 1
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers  Artist_Genres  \
# 4      True  Ignis                 90            300000  (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 4                3.33

# %%
#26. Show albums released after 2021.
df[df['Album_Release_Date'].dt.year > 2021]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 3                3.00
# 4                3.33

# %%
#27. Get tracks with track_number ≤ 3.
df[df["Track_Number"] <= 3]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.92
# 3                3.00

# %%
#28. Filter rows where track_name starts with “F”.
df[df['Track_Name'].str.startswith("F", na=False)]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers  Artist_Genres  \
# 4      True  Ignis                 90            300000  (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 4                3.33

# %%
#29. Get rows where track_popularity is between 60 and 90.
df[(df['Track_Popularity'] > 60) & (df['Track_Popularity'] < 90)]
# Out:
# Empty DataFrame
# Columns: [Track_Id, Track_Name, Track_Number, Track_Popularity, Track_Duration_Ms, Explicit, Singer, Artist_Popularity, Artist_Followers, Artist_Genres, Album_Name, Album_Release_Date, Album_Total_Tracks, Album_Type, track_duration_min]
# Index: []

# %%
df[df["Track_Popularity"].between(60,90, inclusive="neither")]
# Out:
# Empty DataFrame
# Columns: [Track_Id, Track_Name, Track_Number, Track_Popularity, Track_Duration_Ms, Explicit, Singer, Artist_Popularity, Artist_Followers, Artist_Genres, Album_Name, Album_Release_Date, Album_Total_Tracks, Album_Type, track_duration_min]
# Index: []

# %%
df[df["Track_Popularity"].between(60,90, inclusive="both")]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False   Echo                 65             40000  (indie, ambient)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2  Dreamland         2019-09-20                   9      album
#
#    track_duration_min
# 2                3.92

# %%
df[df["Track_Popularity"].between(60,90, inclusive="right")]
# Out:
# Empty DataFrame
# Columns: [Track_Id, Track_Name, Track_Number, Track_Popularity, Track_Duration_Ms, Explicit, Singer, Artist_Popularity, Artist_Followers, Artist_Genres, Album_Name, Album_Release_Date, Album_Total_Tracks, Album_Type, track_duration_min]
# Index: []

# %%
df[df["Track_Popularity"].between(60,90, inclusive="left")]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False   Echo                 65             40000  (indie, ambient)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2  Dreamland         2019-09-20                   9      album
#
#    track_duration_min
# 2                3.92

# %%
#30. Get tracks where album_type is “single”.
df[df["Album_Type"] == "single"]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers  Artist_Genres  \
# 4      True  Ignis                 90            300000  (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 4                3.33

# %%
#31. Filter rows using .query().
df.query("Track_Number == 2")
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 3                 3.0

# %%
#32. Get rows where artist_popularity < 75.
df[df["Artist_Popularity"] < 75]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.92
# 3                3.00

# %%
#33. Get tracks where artist_name is “Nova” or “Echo”.
df[df["Singer"].isin(["Nova", "Echo"])]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False   Echo                 65             40000  (indie, ambient)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2  Dreamland         2019-09-20                   9      album
#
#    track_duration_min
# 2                3.92

# %%
#34. Show tracks with even track_numbers.
df[df["Track_Number"] % 2 == 0]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 3                3.00
# 4                3.33

# %%
df.query("Track_Number % 2 == 0")
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 3     T004  Ocean Blue             2              92.0             180000
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 3                3.00
# 4                3.33

# %%
#35. Show rows where album_name contains “e”.
df[df["Album_Name"].str.contains("e", case=False, na=False)]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
# 4     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 2                3.92
# 3                3.00
# 4                3.33

# %%
#36 Filter rows where track_name has more than 8 characters.
df[df["Track_Name"].str.len() > 8]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
# 4     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 2                3.92
# 3                3.00
# 4                3.33

# %%
#37. Filter using multiple conditions (AND).
df[(df["Track_Id"].str.startswith("T")) & (df["Track_Popularity"] >= 60)]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.92
# 3                3.00

# %%
#38. Filter using OR.
df[(df["Track_Id"].str.startswith("T")) | (df["Track_Popularity"] >= 60)]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
# 4     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
# 4      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
# 4       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 2                3.92
# 3                3.00
# 4                3.33

# %%
#39. Filter using ~ (NOT).
df[~((df["Track_Id"].str.startswith("T")) & (df["Track_Popularity"] >= 60))]
# Out:
#   Track_Id  Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 4     T005  Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers  Artist_Genres  \
# 4      True  Ignis                 90            300000  (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 4                3.33

# %%
#40. Select rows based on index list.
index_list = [2, 3]
df.loc[index_list]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 3     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False      Echo                 65             40000  (indie, ambient)
# 3     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2   Dreamland         2019-09-20                   9      album
# 3  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.92
# 3                3.00

# %%
index_list = [0, 2]
df.iloc[index_list]
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T003  Lost Dreams             3              60.0             235000
# 4     T005   Fire Heart             8              55.0             200000
#
#    Explicit Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2     False   Echo                 65             40000  (indie, ambient)
# 4      True  Ignis                 90            300000     (rock, metal)
#
#   Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2  Dreamland         2019-09-20                   9      album
# 4      Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 2                3.92
# 4                3.33

# %%
# Reset index
from tabulate import tabulate

print("Before resetting index:")
print(tabulate(df, headers='keys', tablefmt='psql'))

df = df.reset_index(drop=True)

print("\nAfter resetting index:")
print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# Before resetting index:
# +----+------------+--------------+----------------+--------------------+---------------------+------------+----------+---------------------+--------------------+----------------------+--------------+----------------------+----------------------+--------------+----------------------+
# |    | Track_Id   | Track_Name   |   Track_Number |   Track_Popularity |   Track_Duration_Ms | Explicit   | Singer   |   Artist_Popularity |   Artist_Followers | Artist_Genres        | Album_Name   | Album_Release_Date   |   Album_Total_Tracks | Album_Type   |   track_duration_min |
# |----+------------+--------------+----------------+--------------------+---------------------+------------+----------+---------------------+--------------------+----------------------+--------------+----------------------+----------------------+--------------+----------------------|
# ...

# %% [markdown]
# #C. Sorting (41–50)

# %%
#41. Sort by track popularity.
df.sort_values("Track_Popularity", ascending=True)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T005   Fire Heart             8              55.0             200000
# 0     T003  Lost Dreams             3              60.0             235000
# 1     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2      True     Ignis                 90            300000     (rock, metal)
# 0     False      Echo                 65             40000  (indie, ambient)
# 1     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2       Blaze         2023-08-12                  13     single
# 0   Dreamland         2019-09-20                   9      album
# 1  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.33
# 0                3.92
# 1                3.00

# %%
#42. Sort by track_duration_ms descending.
df.sort_values("Track_Duration_Ms", ascending=False)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 0     T003  Lost Dreams             3              60.0             235000
# 2     T005   Fire Heart             8              55.0             200000
# 1     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 0     False      Echo                 65             40000  (indie, ambient)
# 2      True     Ignis                 90            300000     (rock, metal)
# 1     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 0   Dreamland         2019-09-20                   9      album
# 2       Blaze         2023-08-12                  13     single
# 1  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 0                3.92
# 2                3.33
# 1                3.00

# %%
#43. Sort by artist_popularity then track_popularity.
df.sort_values(
    ["Artist_Popularity", "Track_Popularity"],
    ascending=[True, True]
)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 0     T003  Lost Dreams             3              60.0             235000
# 1     T004   Ocean Blue             2              92.0             180000
# 2     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 0     False      Echo                 65             40000  (indie, ambient)
# 1     False  BlueWave                 74            120000  (chill, ambient)
# 2      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 0   Dreamland         2019-09-20                   9      album
# 1  Sea Breeze         2022-02-05                  11      album
# 2       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 0                3.92
# 1                3.00
# 2                3.33

# %%
#44. Sort by album_release_date newest → oldest.
df.sort_values("Album_Release_Date", ascending=False)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T005   Fire Heart             8              55.0             200000
# 1     T004   Ocean Blue             2              92.0             180000
# 0     T003  Lost Dreams             3              60.0             235000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2      True     Ignis                 90            300000     (rock, metal)
# 1     False  BlueWave                 74            120000  (chill, ambient)
# 0     False      Echo                 65             40000  (indie, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2       Blaze         2023-08-12                  13     single
# 1  Sea Breeze         2022-02-05                  11      album
# 0   Dreamland         2019-09-20                   9      album
#
#    track_duration_min
# 2                3.33
# 1                3.00
# 0                3.92

# %%
#45. Sort by track_name alphabetically.
df.sort_values("Track_Name", ascending=True)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 2     T005   Fire Heart             8              55.0             200000
# 0     T003  Lost Dreams             3              60.0             235000
# 1     T004   Ocean Blue             2              92.0             180000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 2      True     Ignis                 90            300000     (rock, metal)
# 0     False      Echo                 65             40000  (indie, ambient)
# 1     False  BlueWave                 74            120000  (chill, ambient)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 2       Blaze         2023-08-12                  13     single
# 0   Dreamland         2019-09-20                   9      album
# 1  Sea Breeze         2022-02-05                  11      album
#
#    track_duration_min
# 2                3.33
# 0                3.92
# 1                3.00

# %%
#46. Sort and reset index.
df.sort_values("Track_Id", ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 0     T003  Lost Dreams             3              60.0             235000
# 1     T004   Ocean Blue             2              92.0             180000
# 2     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 0     False      Echo                 65             40000  (indie, ambient)
# 1     False  BlueWave                 74            120000  (chill, ambient)
# 2      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 0   Dreamland         2019-09-20                   9      album
# 1  Sea Breeze         2022-02-05                  11      album
# 2       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 0                3.92
# 1                3.00
# 2                3.33

# %%
#47. Sort only numeric columns.
num_columns = df.select_dtypes("number").columns.tolist()

df.sort_values(by=num_columns)
# Out:
#   Track_Id   Track_Name  Track_Number  Track_Popularity  Track_Duration_Ms  \
# 1     T004   Ocean Blue             2              92.0             180000
# 0     T003  Lost Dreams             3              60.0             235000
# 2     T005   Fire Heart             8              55.0             200000
#
#    Explicit    Singer  Artist_Popularity  Artist_Followers     Artist_Genres  \
# 1     False  BlueWave                 74            120000  (chill, ambient)
# 0     False      Echo                 65             40000  (indie, ambient)
# 2      True     Ignis                 90            300000     (rock, metal)
#
#    Album_Name Album_Release_Date  Album_Total_Tracks Album_Type  \
# 1  Sea Breeze         2022-02-05                  11      album
# 0   Dreamland         2019-09-20                   9      album
# 2       Blaze         2023-08-12                  13     single
#
#    track_duration_min
# 1                3.00
# 0                3.92
# 2                3.33

# %%
#48. Custom sort by album_type (“album” first).
